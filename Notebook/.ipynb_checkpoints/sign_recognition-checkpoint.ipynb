# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img
from tensorflow.keras.utils import to_categorical
# %matplotlib inline

# %%
train_path = '/home/saurabh/Datasets/GSRTB/data/Train'
image_height = 30
image_width = 30

# %%
number_of_categories = len(os.listdir(train_path))
print(number_of_categories)
# Out:
# 43

# %%
img_dir = pathlib.Path(train_path)
plt.figure(figsize=(20,20))
index = 0
for i in range(number_of_categories):
    plt.subplot(8, 8, i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    sign = list(img_dir.glob(f'{i}/*'))[0]
    img = load_img(sign, target_size=(image_width, image_height))
    plt.imshow(img)
plt.show()

# %%
def load_data(data_dir):
    images = list()
    labels = list()
    for category in range(number_of_categories):
        categories = os.path.join(data_dir, str(category))
        for image in os.listdir(categories):
            img = load_img(os.path.join(categories, image), target_size=(30, 30))
            image = img_to_array(img)
            images.append(image)
            labels.append(category)
    return images, labels

# %%
images, labels = load_data(train_path)

# %%
labels = to_categorical(labels)

# %%
labels.shape
# Out:
# (39209, 43)

# %%
x_train, x_test, y_train, y_test = train_test_split(np.array(images), labels, test_size=0.2)

# %%
x_train.shape
# Out:
# (31367, 30, 30, 3)

# %%
data = ImageDataGenerator(rescale=1./255, validation_split=0.1)

# %%
train = data.flow_from_directory(directory='/home/saurabh/Datasets/GSRTB/data/Train',
                                target_size=(image_height,image_width),
                                batch_size=32,
                                class_mode='categorical',
                                subset='training')
val = data.flow_from_directory(directory='/home/saurabh/Datasets/GSRTB/data/Train',
                                target_size=(image_height,image_width),
                                batch_size=32,
                                class_mode='categorical',
                                subset='validation')
# Out:
# Found 35289 images belonging to 43 classes.
# Found 3920 images belonging to 43 classes.

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential

# %%
model = Sequential([
    Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=(image_height,image_width,3)),
    MaxPool2D(pool_size=(2,2)),
    Conv2D(filters=64, kernel_size=3, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    Conv2D(filters=64, kernel_size=3, activation='relu'),
    MaxPool2D(pool_size=(2,2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(number_of_categories, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                2795
# =================================================================
# Total params: 75,563
# Trainable params: 75,563
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(train, epochs=30, steps_per_epoch=60, validation_data=val)
# Out:
# Epoch 1/30
# 60/60 [==============================] - 12s 205ms/step - loss: 3.6047 - accuracy: 0.0604 - val_loss: 3.4811 - val_accuracy: 0.1304
# Epoch 2/30
# 60/60 [==============================] - 13s 217ms/step - loss: 3.2738 - accuracy: 0.1349 - val_loss: 3.3500 - val_accuracy: 0.1436
# Epoch 3/30
# 60/60 [==============================] - 13s 213ms/step - loss: 2.9813 - accuracy: 0.2115 - val_loss: 2.9989 - val_accuracy: 0.2046
# Epoch 4/30
# 60/60 [==============================] - 13s 214ms/step - loss: 2.6863 - accuracy: 0.2734 - val_loss: 2.7502 - val_accuracy: 0.2658
# Epoch 5/30
# 60/60 [==============================] - 13s 211ms/step - loss: 2.1630 - accuracy: 0.4099 - val_loss: 2.4401 - val_accuracy: 0.3293
# Epoch 6/30
# 60/60 [==============================] - 13s 213ms/step - loss: 1.8557 - accuracy: 0.4599 - val_loss: 2.1072 - val_accuracy: 0.3809
# Epoch 7/30
# 60/60 [==============================] - 12s 199ms/step - loss: 1.6151 - accuracy: 0.5135 - val_loss: 1.7879 - val_accuracy: 0.4658
# Epoch 8/30
# 60/60 [==============================] - 13s 221ms/step - loss: 1.3781 - accuracy: 0.5818 - val_loss: 1.6867 - val_accuracy: 0.4985
# Epoch 9/30
# 60/60 [==============================] - 14s 230ms/step - loss: 1.1970 - accuracy: 0.6383 - val_loss: 1.5024 - val_accuracy: 0.5885
# Epoch 10/30
# 60/60 [==============================] - 12s 201ms/step - loss: 1.0462 - accuracy: 0.6818 - val_loss: 1.3004 - val_accuracy: 0.6367
# Epoch 11/30
# 60/60 [==============================] - 14s 232ms/step - loss: 0.8777 - accuracy: 0.7323 - val_loss: 1.2858 - val_accuracy: 0.6153
# Epoch 12/30
# 60/60 [==============================] - 11s 187ms/step - loss: 0.7705 - accuracy: 0.7719 - val_loss: 1.1811 - val_accuracy: 0.6605
# Epoch 13/30
# 60/60 [==============================] - 12s 207ms/step - loss: 0.7324 - accuracy: 0.7740 - val_loss: 1.1523 - val_accuracy: 0.6673
# Epoch 14/30
# 60/60 [==============================] - 13s 223ms/step - loss: 0.6414 - accuracy: 0.8057 - val_loss: 0.9960 - val_accuracy: 0.7334
# Epoch 15/30
# 60/60 [==============================] - 12s 205ms/step - loss: 0.5627 - accuracy: 0.8245 - val_loss: 0.9444 - val_accuracy: 0.7454
# Epoch 16/30
# 60/60 [==============================] - 12s 202ms/step - loss: 0.5695 - accuracy: 0.8276 - val_loss: 0.9123 - val_accuracy: 0.7418
# Epoch 17/30
# 60/60 [==============================] - 14s 231ms/step - loss: 0.5192 - accuracy: 0.8406 - val_loss: 0.9672 - val_accuracy: 0.7321
# Epoch 18/30
# 60/60 [==============================] - 13s 224ms/step - loss: 0.4356 - accuracy: 0.8646 - val_loss: 0.9467 - val_accuracy: 0.7452
# Epoch 19/30
# 60/60 [==============================] - 13s 214ms/step - loss: 0.4804 - accuracy: 0.8594 - val_loss: 0.9247 - val_accuracy: 0.7658
# Epoch 20/30
# 60/60 [==============================] - 13s 223ms/step - loss: 0.3748 - accuracy: 0.8885 - val_loss: 1.1633 - val_accuracy: 0.7250
# Epoch 21/30
# 60/60 [==============================] - 12s 202ms/step - loss: 0.3947 - accuracy: 0.8693 - val_loss: 0.7957 - val_accuracy: 0.8000
# Epoch 22/30
# 60/60 [==============================] - 13s 219ms/step - loss: 0.3501 - accuracy: 0.8927 - val_loss: 0.7295 - val_accuracy: 0.8003
# Epoch 23/30
# 60/60 [==============================] - 13s 220ms/step - loss: 0.3455 - accuracy: 0.9062 - val_loss: 0.7456 - val_accuracy: 0.7977
# Epoch 24/30
# 60/60 [==============================] - 12s 206ms/step - loss: 0.3342 - accuracy: 0.8970 - val_loss: 0.7202 - val_accuracy: 0.8242
# Epoch 25/30
# 60/60 [==============================] - 12s 198ms/step - loss: 0.2796 - accuracy: 0.9146 - val_loss: 0.7823 - val_accuracy: 0.8005
# Epoch 26/30
# 60/60 [==============================] - 13s 213ms/step - loss: 0.3117 - accuracy: 0.9125 - val_loss: 0.6651 - val_accuracy: 0.8247
# Epoch 27/30
# 60/60 [==============================] - 13s 219ms/step - loss: 0.2572 - accuracy: 0.9214 - val_loss: 0.7071 - val_accuracy: 0.8219
# Epoch 28/30
# 60/60 [==============================] - 12s 200ms/step - loss: 0.2685 - accuracy: 0.9153 - val_loss: 0.6930 - val_accuracy: 0.8347
# Epoch 29/30
# 60/60 [==============================] - 12s 192ms/step - loss: 0.2585 - accuracy: 0.9224 - val_loss: 0.7802 - val_accuracy: 0.8133
# Epoch 30/30
# 60/60 [==============================] - 14s 226ms/step - loss: 0.2563 - accuracy: 0.9203 - val_loss: 0.6196 - val_accuracy: 0.8469

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('test set accuracy: ', accuracy * 100)
# Out:
# 246/246 [==============================] - 7s 28ms/step - loss: 4308.6533 - accuracy: 0.0502
# test set accuracy:  5.024228617548943

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(30)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save('/home/saurabh/Datasets/GSRTB/Notebook/Model/')

# %%
model.save('/home/saurabh/Datasets/GSRTB/Notebook/Model/my_model.h5')

# %%
test_path = '/home/saurabh/Datasets/GSRTB/data'

# %%
from sklearn.metrics import accuracy_score
import pandas as pd

Y_test = pd.read_csv('/home/saurabh/Datasets/GSRTB/data/Test.csv')
test_labels = Y_test["ClassId"].values
test_images = Y_test["Path"].values

output = list()
for img in test_images:
    image = load_img(os.path.join(test_path, img), target_size=(30, 30))
    output.append(np.array(image))

X_test=np.array(output)
pred = model.predict_classes(X_test)

#Accuracy with the test data
print('Test Data accuracy: ',accuracy_score(test_labels, pred)*100)
# Out:
# WARNING:tensorflow:From <ipython-input-31-abd15e9065e7>:14: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Test Data accuracy:  5.154394299287411

# %%
plt.figure(figsize = (13, 13))

start_index = 0
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    prediction = pred[start_index + i]
    actual = test_labels[start_index + i]
    col = 'g'
    if prediction != actual:
        col = 'r'
    plt.xlabel('Actual={} || Pred={}'.format(actual, prediction), color = col)
    plt.imshow(X_test[start_index + i])
plt.show()

# %%
def predict(path):
    img = load_img(path, target_size=(30, 30))
    return model.predict_classes(img)
